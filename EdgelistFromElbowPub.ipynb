# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
for year in range(1992,2019):
    subset = "C://Users//amitd//Desktop//FA//SubsetAuthorFrequency-"+str(year)+".csv"
    linkedlist = "C://Users//amitd//Desktop//FA//publication//publication//publication-linkedlist-"+str(year)+".csv"
    newdf = pd.DataFrame(columns=['Auth1', 'Auth2'])
    print("Length newdf="+str(len(newdf)))
    df = pd.read_csv(subset)
    df1 = pd.read_csv(linkedlist)

    list = df['Author'].values.tolist()
    print("Length list="+str(len(list)))
    newname = "AuthorSubsetLinkedlist"+str(year)+".csv"
    for i in range(len(df1)):
        if (df1.Auth1[i] or df1.Auth2[i]) in list:
            newdf = newdf.append({'Auth1': df1.Auth1[i], 'Auth2': df1.Auth2[i]}, ignore_index=True)
        else:
            continue
    newdf.to_csv(newname,index=False)
    print(year)
# Out:
# Length newdf=0
# Length list=7543
# 1992
# Length newdf=0
# Length list=8623
# 1993
# Length newdf=0
# Length list=9145
# 1994
# Length newdf=0
# Length list=10139
# 1995
# Length newdf=0
# Length list=10050
# 1996
# Length newdf=0
# Length list=10881
# 1997
# Length newdf=0
# Length list=12143
# 1998
# Length newdf=0
# Length list=13610
# 1999
# Length newdf=0
# Length list=14641
# 2000
# Length newdf=0
# Length list=14595
# 2001
# Length newdf=0
# Length list=14365
# 2002
# Length newdf=0
# Length list=14758
# 2003
# Length newdf=0
# Length list=16166
# 2004
# Length newdf=0
# Length list=16950
# 2005
# Length newdf=0
# Length list=17521
# 2006
# Length newdf=0
# Length list=18203
# 2007
# Length newdf=0
# Length list=18314
# 2008
# Length newdf=0
# Length list=19662
# 2009
# Length newdf=0
# Length list=20191
# 2010
# Length newdf=0
# Length list=21593
# 2011
# Length newdf=0
# Length list=22180
# 2012
# Length newdf=0
# Length list=22138
# 2013
# Length newdf=0
# ...
