# %%
import pandas as pd
import numpy as np

# %%
MasterAuthor = pd.read_csv("C://Users//amitd//Desktop//FA//AuthorlevelMetrics//rstudio-export//Book1.csv")

# %%
all_authors = MasterAuthor["Author"].tolist()

# %%
MasterAuthor.head()
# Out:
#                     Author  1997  1998  1999  2000  2001  2002  2003  2004  \
# 0             Yoshimura,K.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1               Gautier,M.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                    Hu,F.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  Vanlerberghe-Masutti,F.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                   Ito,E.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2005  ...  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 22 columns]

# %%
all_authors[0:5]
# Out:
# ['Yoshimura,K.', 'Gautier,M.', 'Hu,F.', 'Vanlerberghe-Masutti,F.', 'Ito,E.']

# %%
type(all_authors)
# Out:
# list

# %%
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append(row)
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

# %%
dfwindow = pd.DataFrame(columns = ["Author",'Window1','Window2','Window3','Window4','Window5','Window6','Window7'])
dfwindow
# Out:
# Empty DataFrame
# Columns: [Author, Window1, Window2, Window3, Window4, Window5, Window6, Window7]
# Index: []

# %%
dfwindow["Author"] = MasterAuthor["Author"]

# %%
dfwindow.head(10)
# Out:
#                     Author Window1 Window2 Window3 Window4 Window5 Window6  \
# 0             Yoshimura,K.     NaN     NaN     NaN     NaN     NaN     NaN
# 1               Gautier,M.     NaN     NaN     NaN     NaN     NaN     NaN
# 2                    Hu,F.     NaN     NaN     NaN     NaN     NaN     NaN
# 3  Vanlerberghe-Masutti,F.     NaN     NaN     NaN     NaN     NaN     NaN
# 4                   Ito,E.     NaN     NaN     NaN     NaN     NaN     NaN
# 5                Wang,J.L.     NaN     NaN     NaN     NaN     NaN     NaN
# 6                  Mayo,M.     NaN     NaN     NaN     NaN     NaN     NaN
# 7              Kawakami,Y.     NaN     NaN     NaN     NaN     NaN     NaN
# 8                   Lin,R.     NaN     NaN     NaN     NaN     NaN     NaN
# 9             O'Neill,R.J.     NaN     NaN     NaN     NaN     NaN     NaN
#
#   Window7
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
start_year = 1997
interval = 2
end_year= start_year+interval
for i in range(1,2):
    co_auth = []###Initiating empty coauthor list
    for j in range(start_year,end_year):###Looping in Windows eg 1997-1999
        print(j)
        df = pd.read_csv("C://Users//amitd//Desktop//FA//IntersectedAuthors"+str(start_year)+".csv")###Reading file for that year
        for index, author in enumerate(all_authors):###Looping through author list
            listofindex = getIndexes(df,author)###Getting index of occurence of that author in df
            if len(listofindex)==0:###If author absent in that year, move to next author
                continue
            for idx in listofindex:
                co_auth1=df.loc[ idx , : ].dropna().tolist()
                co_auth.extend(co_auth1)
                uniq = list(set(co_auth))
                uniq.remove(author)
    strWin = "Window"+str(i)
    dfwindow[strWin][index] = uniq         
    start_year= end_year+1
    end_year= start_year+interval
# Out:
# 1997
# 1997

# %%
for j in range(1997,2018):###Looping in Windows eg 1997-1999
    print(j)
    df = pd.read_csv("C://Users//amitd//Desktop//FA//IntersectedAuthors"+str(j)+".csv")###Reading file for that year
    for index, author in enumerate(all_authors):###Looping through author list
        co_auth = []###Initiating empty coauthor list
        listofindex = getIndexes(df,author)###Getting index of occurence of that author in df
        if len(listofindex)==0:###If author absent in that year, move to next author
            continue
        for idx in listofindex:
            co_auth1=df.loc[ idx , : ].dropna().tolist()
            co_auth.extend(co_auth1)
        uniq = list(set(co_auth))
        uniq.remove(author)
        MasterAuthor[str(j)][index]=uniq
# Out:
# 1997
# C:\Users\amitd\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1998
# 1999
# ...

# %%
len(MasterAuthor["1998"][2])
# Out:
# 10

# %%
MasterAuthor.head(15)
# Out:
#                      Author  \
# 0              Yoshimura,K.
# 1                Gautier,M.
# 2                     Hu,F.
# 3   Vanlerberghe-Masutti,F.
# 4                    Ito,E.
# 5                 Wang,J.L.
# 6                   Mayo,M.
# 7               Kawakami,Y.
# 8                    Lin,R.
# 9              O'Neill,R.J.
# 10              Fujiwara,T.
# 11             Nishiyama,T.
# 12             Nishizawa,M.
# 13                   Cao,J.
# 14                   Lan,Q.
#
#                                                  1997  \
# 0   [Shigeoka,S., Suyama,Y., Tsumura,Y., Shirato,N...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [Nomura,N., Yokoyama,M., Igarashi,K., Kitazawa...
# 5                                                 NaN
# 6                                                 NaN
# 7   [Kamio,Y., Wada,N., Kimura,T., Nohno,T., Kanek...
# ...

# %%
MasterAuthor.to_csv("Coauthors65.csv")

# %%
MasterAuthor["1998"][2]
# Out:
# ['Portnoy,J.', 'Barnes,C.', 'Landuyt,J.', 'Rosenthal,D.', 'Pacheco,F.']

# %%
MasterAuthor["1999"][2]
# Out:
# ['Suo,M.', 'Zhao,H.', 'Dong,S.', 'Ma,S.', 'Li,Q.']

# %%
MasterAuthor["1997"][2]
# Out:
# nan

# %%
start_year = 1997
interval = 2
end_year= start_year+interval
for i in range(1,8):
    co_auth = []###Initiating empty coauthor list
    for j in range(start_year,end_year):###Looping in Windows eg 1997-1999

# %%
newmaster=MasterAuthor.copy()

# %%
newmaster.head()
# Out:
#                     Author                                               1997  \
# 0             Yoshimura,K.  [Shigeoka,S., Suyama,Y., Tsumura,Y., Shirato,N...
# 1               Gautier,M.                                                NaN
# 2                    Hu,F.                                                NaN
# 3  Vanlerberghe-Masutti,F.                                                NaN
# 4                   Ito,E.  [Nomura,N., Yokoyama,M., Igarashi,K., Kitazawa...
#
#                                                 1998  \
# 0                                                NaN
# 1           [Chopin,M.C., Schouler,C., Ehrlich,S.D.]
# 2  [Portnoy,J., Barnes,C., Landuyt,J., Rosenthal,...
# 3                                                NaN
# 4  [Iwahashi,Y., Akiyama,Y., Yanagisawa,Y., Yuasa...
#
#                                                 1999  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
len(dfwindow['Window2'][4])
# Out:
# 37

# %%
newmaster = newmaster.apply(lambda s: s.fillna({i: [] for i in newmaster.index}))###To replace nan with empty list to enable list processing ahead
newmaster.head()
# Out:
#                     Author                                               1997  \
# 0             Yoshimura,K.  [Shigeoka,S., Suyama,Y., Tsumura,Y., Shirato,N...
# 1               Gautier,M.                                                 []
# 2                    Hu,F.                                                 []
# 3  Vanlerberghe-Masutti,F.                                                 []
# 4                   Ito,E.  [Nomura,N., Yokoyama,M., Igarashi,K., Kitazawa...
#
#                                                 1998  \
# 0                                                 []
# 1           [Chopin,M.C., Schouler,C., Ehrlich,S.D.]
# 2  [Portnoy,J., Barnes,C., Landuyt,J., Rosenthal,...
# 3                                                 []
# 4  [Iwahashi,Y., Akiyama,Y., Yanagisawa,Y., Yuasa...
#
#                                                 1999  \
# 0                                                 []
# 1                                                 []
# ...

# %%
newmaster['1997'][4]
# Out:
# ['Nomura,N.',
#  'Yokoyama,M.',
#  'Igarashi,K.',
#  'Kitazawa,J.',
#  'Akasaka,J.',
#  'Toki,T.',
#  'Itoh,J.',
#  'Yamamoto,M.',
#  'Hatakeyama,K.',
#  'Arai,K.']

# %%
newmaster['1998'][4]
# Out:
# ['Iwahashi,Y.',
#  'Akiyama,Y.',
#  'Yanagisawa,Y.',
#  'Yuasa,Y.',
#  'Maruyama,K.',
#  'Onodera,T.']

# %%
newmaster['1999'][4]
# Out:
# ['Hayashi,N.',
#  'Suzuki,Y.',
#  'Yanagisawa,Y.',
#  'Takahashi,S.',
#  'Toki,T.',
#  'Yuasa,Y.',
#  'Sharma,M.',
#  'Palmer,P.P.',
#  'Maruyama,K.',
#  'Kobayashi,A.',
#  'Xie,G.X.',
#  'Yamamoto,M.',
#  'Kogame,K.',
#  'Pietruck,C.',
#  'Iwahashi,Y.',
#  'Akiyama,Y.',
#  'Nagasaki,H.',
#  'Yuasa,Y',
#  'Sugano,S.',
#  'Igarashi,K.',
#  ',Maruyama,K.']

# %%
dfwindow['Window1']=newmaster["1997"]+newmaster['1998']+newmaster['1999']###Merging into windows
dfwindow['Window2']=newmaster["2000"]+newmaster['2001']+newmaster['2002']
dfwindow['Window3']=newmaster["2003"]+newmaster['2004']+newmaster['2005']
dfwindow['Window4']=newmaster["2006"]+newmaster['2007']+newmaster['2008']
dfwindow['Window5']=newmaster["2009"]+newmaster['2010']+newmaster['2011']
dfwindow['Window6']=newmaster["2012"]+newmaster['2013']+newmaster['2014']
dfwindow['Window7']=newmaster["2015"]+newmaster['2016']+newmaster['2017']

# %%
dfwindow.head()
# Out:
#                     Author                                            Window1  \
# 0             Yoshimura,K.  [Shigeoka,S., Suyama,Y., Tsumura,Y., Shirato,N...
# 1               Gautier,M.           [Chopin,M.C., Schouler,C., Ehrlich,S.D.]
# 2                    Hu,F.  [Portnoy,J., Barnes,C., Landuyt,J., Rosenthal,...
# 3  Vanlerberghe-Masutti,F.             [Fuller,S.J., Chavigny,P., Lapchin,L.]
# 4                   Ito,E.  [Nomura,N., Yokoyama,M., Igarashi,K., Kitazawa...
#
#                                              Window2  \
# 0  [Nomura,M., ,Tsumura,Y., Inoue,S., Ujino-Ihara...
# 1  [Leroux,C., Taourit,S., Chilliard,Y., Osta,R.,...
# 2  [Bhattacharjee,A., Goswami,T., Dong,S., Zhang,...
# 3  [Castagnone-Sereno,P., Auge-Gouillou,C., Pizzo...
# 4  [Toki,T., Umenai,T., Sharma,M., Palmer,P.P., N...
#
#                                              Window3  \
# 0  [Moriguchi,Y., Ujino-Ihara,T., Ihara,T., Taira...
# 1  [Lingaas,F., Asheim,H.-C., Ronningen,K., Olsak...
# ...

# %%
dfwindow['Window1']=dfwindow['Window1'].apply(lambda x:list(set(x)))###Taking set to retain only unique values

# %%
dfwindow['Window2']=dfwindow['Window2'].apply(lambda x:list(set(x)))###Taking set to retain only unique values
dfwindow['Window3']=dfwindow['Window3'].apply(lambda x:list(set(x)))
dfwindow['Window4']=dfwindow['Window4'].apply(lambda x:list(set(x)))
dfwindow['Window5']=dfwindow['Window5'].apply(lambda x:list(set(x)))
dfwindow['Window6']=dfwindow['Window6'].apply(lambda x:list(set(x)))
dfwindow['Window7']=dfwindow['Window7'].apply(lambda x:list(set(x)))

# %%
dfwindow.head()
# Out:
#                     Author                                            Window1  \
# 0             Yoshimura,K.  [Shigeoka,S., Suyama,Y., Tsumura,Y., Mukai,Y.,...
# 1               Gautier,M.           [Chopin,M.C., Schouler,C., Ehrlich,S.D.]
# 2                    Hu,F.  [Suo,M., Portnoy,J., Zhao,H., Dong,S., Barnes,...
# 3  Vanlerberghe-Masutti,F.             [Fuller,S.J., Chavigny,P., Lapchin,L.]
# 4                   Ito,E.  [Hayashi,N., Suzuki,Y., Yanagisawa,Y., Takahas...
#
#                                              Window2  \
# 0  [Nomura,M., ,Tsumura,Y., Inoue,S., Ujino-Ihara...
# 1  [Leroux,C., Taourit,S., Chilliard,Y., Rouault,...
# 2  [Goswami,T., Bhattacharjee,A., Dong,S., Zhang,...
# 3  [Castagnone-Sereno,P., Auge-Gouillou,C., Pizzo...
# 4  [Tauchi,H., Toki,T., Umenai,T., Sharma,M., Pal...
#
#                                              Window3  \
# 0  [Isogai,N., Kanamori,H., Moriguchi,Y., Hirono,...
# 1  [Nilsen,H., Olsen,H.G., Bonsdorff,T., Ihara,N....
# ...

# %%
len(dfwindow['Window1'][4])
# Out:
# 29

# %%
dfwindow1=dfwindow.copy()

# %%
dfwindow1.head(6)
# Out:
#                     Author                                            Window1  \
# 0             Yoshimura,K.  [Shigeoka,S., Suyama,Y., Tsumura,Y., Mukai,Y.,...
# 1               Gautier,M.           [Chopin,M.C., Schouler,C., Ehrlich,S.D.]
# 2                    Hu,F.  [Suo,M., Portnoy,J., Zhao,H., Dong,S., Barnes,...
# 3  Vanlerberghe-Masutti,F.             [Fuller,S.J., Chavigny,P., Lapchin,L.]
# 4                   Ito,E.  [Hayashi,N., Suzuki,Y., Yanagisawa,Y., Takahas...
# 5                Wang,J.L.  [Miranda,C.L., Buhler,D.R., Nguyen,M.H., Yang,...
#
#                                              Window2  \
# 0  [Nomura,M., ,Tsumura,Y., Inoue,S., Ujino-Ihara...
# 1  [Leroux,C., Taourit,S., Chilliard,Y., Rouault,...
# 2  [Goswami,T., Bhattacharjee,A., Dong,S., Zhang,...
# 3  [Castagnone-Sereno,P., Auge-Gouillou,C., Pizzo...
# 4  [Tauchi,H., Toki,T., Umenai,T., Sharma,M., Pal...
# 5                                                 []
#
# ...

# %%
dfwindow1["Window2"][1]
# Out:
# ['Leroux,C.',
#  'Taourit,S.',
#  'Chilliard,Y.',
#  'Rouault,A.',
#  'Osta,R.',
#  'Chopin,M.C.',
#  'Roy,R.',
#  'Eggen,A.',
#  'Laurent,P.',
#  'Hayes,H.',
#  'Bernard,L.',
#  'Rodellar,C.',
#  'Ehrlich,S.D.',
#  'Martin,P.',
#  'Zaragoza,P.']

# %%
dfwindow1["Window1"][1]
# Out:
# ['Chopin,M.C.', 'Schouler,C.', 'Ehrlich,S.D.']

# %%
new_coauth = pd.DataFrame(columns = ["Author",'Window2','Window3','Window4','Window5','Window6','Window7'])###Non-cumm df
new_coauth
# Out:
# Empty DataFrame
# Columns: [Author, Window2, Window3, Window4, Window5, Window6, Window7]
# Index: []

# %%
new_coauth["Author"] = MasterAuthor["Author"]

# %%
for i in range(2,8):
    strg="Window"+str(i)
    strg1="Window"+str(i-1)
    for j in range(len(dfwindow1)):
        new_coauth[strg][j]=len(np.setdiff1d(dfwindow1[strg][j],dfwindow1[strg1][j]))

# %%
dfwindow1[["Window1","Window2"]].head()

# %%
new_coauth.head()
# Out:
#                     Author Window2 Window3 Window4 Window5 Window6 Window7
# 0             Yoshimura,K.      43      19      25      32      15      14
# 1               Gautier,M.      13      25      20       1       9      43
# 2                    Hu,F.      11      19      28      70      50     132
# 3  Vanlerberghe-Masutti,F.       9       4       1      13       7       8
# 4                   Ito,E.      35      32       8       8       8      16

# %%
new_coauthcumm = pd.DataFrame(columns = ["Author",'Window2','Window3','Window4','Window5','Window6','Window7'])###Cumm df
new_coauthcumm
# Out:
# Empty DataFrame
# Columns: [Author, Window2, Window3, Window4, Window5, Window6, Window7]
# Index: []

# %%
new_coauthcumm["Author"] = MasterAuthor["Author"]

# %%
for i in range(2,8):
    strg="Window"+str(i)
    strg1="Window"+str(i-1)
    for j in range(len(dfwindow1)):
        if i-1==1:            
            new_coauthcumm[strg][j]=len(np.setdiff1d(dfwindow1[strg][j],dfwindow1[strg1][j]))
        else:
            newlist=[]
            for k in range(1,i):
                strg2 = "Window"+str(k)
                newlist = newlist+dfwindow1[strg2][j]
                new_coauthcumm[strg][j]=len(np.setdiff1d(dfwindow1[strg][j],newlist))

# %%
new_coauthcumm.head(10)
# Out:
#                     Author Window2 Window3 Window4 Window5 Window6 Window7
# 0             Yoshimura,K.      43      17      23      32      15      14
# 1               Gautier,M.      13      25      20       1       9      43
# 2                    Hu,F.      11      19      27      68      49     118
# 3  Vanlerberghe-Masutti,F.       9       4       1      13       7       8
# 4                   Ito,E.      35      28       8       8       8      16
# 5                Wang,J.L.       0      12      16      71      73      41
# 6                  Mayo,M.       3      72      42      45      40      63
# 7              Kawakami,Y.      37      46      21      35      36      12
# 8                   Lin,R.       7       6      16     136      78      39
# 9             O'Neill,R.J.       4      11      14       7       8       8

# %%
new_coauth.head(10)
# Out:
#                     Author Window2 Window3 Window4 Window5 Window6 Window7
# 0             Yoshimura,K.      43      19      25      32      15      14
# 1               Gautier,M.      13      25      20       1       9      43
# 2                    Hu,F.      11      19      28      70      50     132
# 3  Vanlerberghe-Masutti,F.       9       4       1      13       7       8
# 4                   Ito,E.      35      32       8       8       8      16
# 5                Wang,J.L.       0      12      16      72      73      42
# 6                  Mayo,M.       3      72      42      45      40      63
# 7              Kawakami,Y.      37      46      21      37      37      14
# 8                   Lin,R.       7       6      16     138      83      46
# 9             O'Neill,R.J.       4      14      15       7       8       8

# %%
new_coauth.to_csv("Non-Cummulative.csv")
new_coauthcumm.to_csv("Cummulative.csv")
dfwindow.to_csv("All-Coauthors-WindowWise.csv")
