# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
newdf = pd.DataFrame(columns=['Auth1', 'Auth2'])
#newdf = newdf.append({'Auth1':0,'Auth0':1} , ignore_index=True)

newdf
# Out:
# Empty DataFrame
# Columns: [Auth1, Auth2]
# Index: []

# %%
newdf = newdf.drop(newdf.index[0])

# %%
newdf
# Out:
#             Auth1           Auth2
# 0     Norimine,J.     Miyazawa,T.
# 1     Norimine,J.        Tohya,Y.
# 2     Norimine,J.       Mikami,T.
# 3        Maeda,K.     Norimine,J.
# 4     Horimoto,T.     Norimine,J.
# 5     Norimine,J.    Kawaguchi,Y.
# 6     Norimine,J.      Niikura,M.
# 7     Norimine,J.    Takahashi,E.
# 8     Norimine,J.     Miyazawa,T.
# 9     Norimine,J.        Tohya,Y.
# 10    Norimine,J.       Mikami,T.
# 11       Maeda,K.     Norimine,J.
# 12    Horimoto,T.     Norimine,J.
# 13    Norimine,J.    Kawaguchi,Y.
# 14    Norimine,J.      Niikura,M.
# 15    Norimine,J.    Takahashi,E.
# 16    Norimine,J.     Miyazawa,T.
# 17    Norimine,J.        Tohya,Y.
# 18    Norimine,J.       Mikami,T.
# 19       Maeda,K.     Norimine,J.
# 20    Horimoto,T.     Norimine,J.
# 21    Norimine,J.    Kawaguchi,Y.
# 22    Norimine,J.      Niikura,M.
# 23    Norimine,J.    Takahashi,E.
# 24    Norimine,J.     Miyazawa,T.
# 25    Norimine,J.        Tohya,Y.
# ...

# %%
for i in range(1992,1993):
    subset = "C://Users//amitd//Desktop//FA//SubsetAuthorFrequency-"+str(i)+".csv"
    linkedlist = "C://Users//amitd//Desktop//FA//publication//publication//publication-linkedlist-"+str(i)+".csv"
    df = pd.read_csv(subset)
    df1 = pd.read_csv(linkedlist)
    for j in range(len(df)):
        for k in range(len(df1)):
            #print(i,j,k)
            if (df.iloc[j]['Author']==df1.iloc[k]['Auth1'] or df.iloc[j]['Author']==df1.iloc[k]['Auth2']):
                newdf = newdf.append({'Auth1': df1.iloc[k]['Auth1'], 'Auth2': df1.iloc[k]['Auth2']}, ignore_index=True)
                #df1 = df1.drop(df1.index[k])
            else:
                continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-597e55a3ca79> in <module>
#       7         for k in range(len(df1)):
#       8             #print(i,j,k)
# ----> 9             if (df.iloc[j]['Author']==df1.iloc[k]['Auth1'] or df.iloc[j]['Author']==df1.iloc[k]['Auth2']):
#      10                 newdf = newdf.append({'Auth1': df1.iloc[k]['Auth1'], 'Auth2': df1.iloc[k]['Auth2']}, ignore_index=True)
#      11                 #df1 = df1.drop(df1.index[k])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...
